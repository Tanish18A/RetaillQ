# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
import dotenv

dotenv.load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash"
)

parser = StrOutputParser()

chain = llm | parser

response = chain.invoke("What is AI?")

print(response)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 7
#       3 import dotenv
#       5 dotenv.load_dotenv()
# ----> 7 llm = ChatGoogleGenerativeAI(
#       8     model="gemini-2.0-flash"
#       9 )
#      11 parser = StrOutputParser()
#      13 chain = llm | parser
#
# File d:\Udemy_Prac\DS_and_ML\Python\virtual_env3.12\Lib\site-packages\langchain_google_genai\chat_models.py:2269, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    2262         suggestion = (
#    2263             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    2264         )
#    2265         logger.warning(
#    2266             f"Unexpected argument '{arg}' "
#    2267             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    2268         )
# -> 2269 super().__init__(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for ChatGoogleGenerativeAI
#   Value error, API key required for Gemini Developer API. Provide api_key parameter or set GOOGLE_API_KEY/GEMINI_API_KEY environment variable. [type=value_error, input_value={'model': 'gemini-2.0-flash', 'model_kwargs': {}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error

# %%
# !pip install --upgrade langchain-google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.65.0 (from langchain-google-genai)
#   Downloading google_genai-1.75.0-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.29 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-google-genai) (1.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-google-genai) (2.13.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.8.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.49.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Collecting websockets<17.0,>=13.0.0 (from google-genai<2.0.0,>=1.65.0->langchain-google-genai)
#   Downloading websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai<2.0.0,>=1.65.0->langchain-google-genai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: sniffio in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (46.0.7)
# Requirement already satisfied: certifi in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.8.0)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (6.0.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.3.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Downloading langchain_google_genai-4.2.2-py3-none-any.whl (67 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.75.0-py3-none-any.whl (793 kB)
#    ---------------------------------------- 0.0/793.7 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/793.7 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 793.7/793.7 kB 1.8 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading websockets-16.0-cp312-cp312-win_amd64.whl (178 kB)
# Installing collected packages: filetype, websockets, distro, google-genai, langchain-google-genai
#
#    -------- ------------------------------- 1/5 [websockets]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ---------------------------------------- 5/5 [langchain-google-genai]
#
# Successfully installed distro-1.9.0 filetype-1.2.0 google-genai-1.75.0 langchain-google-genai-4.2.2 websockets-16.0
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip
